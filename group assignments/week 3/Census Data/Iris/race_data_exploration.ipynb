# %% [markdown]
# # Los Angeles Race Data 2018
# This notebook explores race data from the Los Angeles census from 2018.
# Iris Craige

# %%
import pandas as pd

# %%
race_2010 = pd.read_csv(
    '2010_race_data.csv',
    dtype=
    {
        'Geo_FIPS':str,

    }
)

# %% [markdown]
# Imported data for race in Los Angeles in 2010

# %%
race_2010
# Out:
#          Geo_FIPS                                           Geo_NAME  \
# 0     06037101110  Census Tract 1011.10, Los Angeles County, Cali...
# 1     06037101122  Census Tract 1011.22, Los Angeles County, Cali...
# 2     06037101220  Census Tract 1012.20, Los Angeles County, Cali...
# 3     06037101300  Census Tract 1013, Los Angeles County, California
# 4     06037101400  Census Tract 1014, Los Angeles County, California
# ...           ...                                                ...
# 2015  06037980030  Census Tract 9800.30, Los Angeles County, Cali...
# 2016  06037980031  Census Tract 9800.31, Los Angeles County, Cali...
# 2017  06037980033  Census Tract 9800.33, Los Angeles County, Cali...
# 2018  06037990100  Census Tract 9901, Los Angeles County, California
# 2019  06037990200  Census Tract 9902, Los Angeles County, California
#
#                                               Geo_QName Geo_STUSAB  \
# 0     Census Tract 1011.10, Los Angeles County, Cali...         ca
# ...

# %% [markdown]
# Imported data for race in Los Angeles in 2018

# %%
race_2018 = pd.read_csv(
    '2018_race_data.csv',
    dtype=
    {
        'Geo_FIPS':str,

    }
)

# %%
race_2018
# Out:
#          Geo_FIPS              Geo_NAME  \
# 0     06037101110  Census Tract 1011.10
# 1     06037101122  Census Tract 1011.22
# 2     06037101220  Census Tract 1012.20
# 3     06037101300     Census Tract 1013
# 4     06037101400     Census Tract 1014
# ...           ...                   ...
# 2016  06037980030  Census Tract 9800.30
# 2017  06037980031  Census Tract 9800.31
# 2018  06037980033  Census Tract 9800.33
# 2019  06037990100     Census Tract 9901
# 2020  06037990200     Census Tract 9902
#
#                                               Geo_QName Geo_STUSAB  \
# 0     Census Tract 1011.10, Los Angeles County, Cali...         ca
# 1     Census Tract 1011.22, Los Angeles County, Cali...         ca
# 2     Census Tract 1012.20, Los Angeles County, Cali...         ca
# 3     Census Tract 1013, Los Angeles County, California         ca
# 4     Census Tract 1014, Los Angeles County, California         ca
# ...                                                 ...        ...
# ...

# %%
race_2018.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2021 entries, 0 to 2020
# Data columns (total 65 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2021 non-null   object
#  1   Geo_NAME       2021 non-null   object
#  2   Geo_QName      2021 non-null   object
#  3   Geo_STUSAB     2021 non-null   object
#  4   Geo_SUMLEV     2021 non-null   int64
#  5   Geo_GEOCOMP    2021 non-null   int64
#  6   Geo_FILEID     2021 non-null   object
#  7   Geo_LOGRECNO   2021 non-null   int64
#  8   Geo_US         0 non-null      float64
#  9   Geo_REGION     0 non-null      float64
#  10  Geo_DIVISION   0 non-null      float64
#  11  Geo_STATECE    0 non-null      float64
#  12  Geo_STATE      2021 non-null   int64
#  13  Geo_COUNTY     2021 non-null   int64
#  14  Geo_COUSUB     0 non-null      float64
#  15  Geo_PLACE      0 non-null      float64
#  16  Geo_PLACESE    0 non-null      float64
# ...

# %%
race_2018.columns[race_2018.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_PLACESE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_PUMA5',
#  'Geo_PUMA1',
#  'Geo_BTTR',
#  'Geo_BTBG']

# %% [markdown]
# Dropped columns with no data for both data sets

# %%
race_2010 = race_2010.dropna(axis=1,how="all")

# %%
race_2018 = race_2018.dropna(axis=1,how="all")

# %%
race_2018
# Out:
#          Geo_FIPS              Geo_NAME  \
# 0     06037101110  Census Tract 1011.10
# 1     06037101122  Census Tract 1011.22
# 2     06037101220  Census Tract 1012.20
# 3     06037101300     Census Tract 1013
# 4     06037101400     Census Tract 1014
# ...           ...                   ...
# 2016  06037980030  Census Tract 9800.30
# 2017  06037980031  Census Tract 9800.31
# 2018  06037980033  Census Tract 9800.33
# 2019  06037990100     Census Tract 9901
# 2020  06037990200     Census Tract 9902
#
#                                               Geo_QName Geo_STUSAB  \
# 0     Census Tract 1011.10, Los Angeles County, Cali...         ca
# 1     Census Tract 1011.22, Los Angeles County, Cali...         ca
# 2     Census Tract 1012.20, Los Angeles County, Cali...         ca
# 3     Census Tract 1013, Los Angeles County, California         ca
# 4     Census Tract 1014, Los Angeles County, California         ca
# ...                                                 ...        ...
# ...

# %%
race_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2021 entries, 0 to 2020
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2021 non-null   object
#  1   Geo_NAME       2021 non-null   object
#  2   Geo_QName      2021 non-null   object
#  3   Geo_STUSAB     2021 non-null   object
#  4   Geo_SUMLEV     2021 non-null   int64
#  5   Geo_GEOCOMP    2021 non-null   int64
#  6   Geo_FILEID     2021 non-null   object
#  7   Geo_LOGRECNO   2021 non-null   int64
#  8   Geo_STATE      2021 non-null   int64
#  9   Geo_COUNTY     2021 non-null   int64
#  10  Geo_TRACT      2021 non-null   int64
#  11  Geo_GEOID      2021 non-null   object
#  12  Geo_AREALAND   2021 non-null   int64
#  13  Geo_AREAWATR   2021 non-null   int64
#  14  SE_A03001_001  2021 non-null   int64
#  15  SE_A03001_002  2021 non-null   int64
#  16  SE_A03001_003  2021 non-null   int64
#  17  SE_A03001_004  2021 non-null   int64
# ...

# %%
columns_to_keep = [
    'Geo_FIPS',
    'SE_A03001_001',   
    'SE_A03001_002',     
    'SE_A03001_003',    
    'SE_A03001_004',     
    'SE_A03001_005',      
    'SE_A03001_006',     
    'SE_A03001_007',      
    'SE_A03001_008',
]

# %% [markdown]
# Cleaned data to capture columns with relevant data

# %%
race_2018_2 = race_2018[columns_to_keep]

# %%
race_2018_2
# Out:
#          Geo_FIPS  SE_A03001_001  SE_A03001_002  SE_A03001_003  SE_A03001_004  \
# 0     06037101110           4314           3314             47              4
# 1     06037101122           3239           2837             61             13
# 2     06037101220           3497           2494             71              0
# 3     06037101300           4297           3705            161              0
# 4     06037101400           3851           3022             18             43
# ...           ...            ...            ...            ...            ...
# 2016  06037980030              0              0              0              0
# 2017  06037980031           1113            608            234             21
# 2018  06037980033             14              0              0             14
# 2019  06037990100              0              0              0              0
# 2020  06037990200              0              0              0              0
#
# ...

# %%
race_2018_2.columns = [
    'FIPS',
    'Total Population',
    'White Alone',
    'Black or African American Alone',
    'American Indian and Alaska Native Alone',
    'Asian Alone',
    'Native Hawaiian and Other Pacific Islander Alone',
    'Some Other Race Alone',
    'Two or More Races'
]

# %%
race_2018_2
# Out:
#              FIPS  Total Population  White Alone  \
# 0     06037101110              4314         3314
# 1     06037101122              3239         2837
# 2     06037101220              3497         2494
# 3     06037101300              4297         3705
# 4     06037101400              3851         3022
# ...           ...               ...          ...
# 2016  06037980030                 0            0
# 2017  06037980031              1113          608
# 2018  06037980033                14            0
# 2019  06037990100                 0            0
# 2020  06037990200                 0            0
#
#       Black or African American Alone  \
# 0                                  47
# 1                                  61
# 2                                  71
# 3                                 161
# 4                                  18
# ...                               ...
# 2016                                0
# 2017                              234
# ...

# %%
race_2010_2 = race_2010[columns_to_keep]

# %%
race_2010_2.columns = [
    'FIPS',
    'Total Population',
    'White Alone',
    'Black or African American Alone',
    'American Indian and Alaska Native Alone',
    'Asian Alone',
    'Native Hawaiian and Other Pacific Islander Alone',
    'Some Other Race Alone',
    'Two or More Races'
]

# %%
race_2010_2
# Out:
#              FIPS  Total Population  White Alone  \
# 0     06037101110              5017         3879
# 1     06037101122              3663         2617
# 2     06037101220              3189         2364
# 3     06037101300              3808         3436
# 4     06037101400              3733         3131
# ...           ...               ...          ...
# 2015  06037980030                 0            0
# 2016  06037980031               932          481
# 2017  06037980033                 0            0
# 2018  06037990100                 0            0
# 2019  06037990200                 0            0
#
#       Black or African American Alone  \
# 0                                  38
# 1                                   0
# 2                                  23
# 3                                  12
# 4                                 132
# ...                               ...
# 2015                                0
# 2016                              179
# ...

# %% [markdown]
# Created a histogram for Total Population

# %%
race_2010_2['Total Population'].plot.hist(bins=50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
race_2018_2['Total Population'].plot.hist(bins=50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# Created a scatter plot to compare FIPS with different racial components for both years

# %%
race_2010_2.plot.scatter(x='Black or African American Alone',y='White Alone')
# Out:
# <AxesSubplot: xlabel='Black or African American Alone', ylabel='White Alone'>

# %%
race_2018_2.plot.scatter(x='Black or African American Alone',y='White Alone')
# Out:
# <AxesSubplot: xlabel='Black or African American Alone', ylabel='White Alone'>

# %% [markdown]
# Identified FIPS with no population

# %%
race_2010_2[race_2010_2['Total Population']==0]
# Out:
#              FIPS  Total Population  White Alone  \
# 1992  06037980001                 0            0
# 1993  06037980002                 0            0
# 1994  06037980003                 0            0
# 1995  06037980004                 0            0
# 1996  06037980005                 0            0
# 1998  06037980007                 0            0
# 2002  06037980013                 0            0
# 2005  06037980018                 0            0
# 2007  06037980020                 0            0
# 2008  06037980021                 0            0
# 2009  06037980022                 0            0
# 2010  06037980023                 0            0
# 2012  06037980025                 0            0
# 2014  06037980028                 0            0
# 2015  06037980030                 0            0
# 2017  06037980033                 0            0
# 2018  06037990100                 0            0
# 2019  06037990200                 0            0
#
# ...

# %%
race_2018_2[race_2018_2['Total Population']==0]
# Out:
#              FIPS  Total Population  White Alone  \
# 1993  06037980001                 0            0
# 1994  06037980002                 0            0
# 1995  06037980003                 0            0
# 1996  06037980004                 0            0
# 1997  06037980005                 0            0
# 1998  06037980006                 0            0
# 1999  06037980007                 0            0
# 2003  06037980013                 0            0
# 2006  06037980018                 0            0
# 2008  06037980020                 0            0
# 2010  06037980022                 0            0
# 2011  06037980023                 0            0
# 2013  06037980025                 0            0
# 2015  06037980028                 0            0
# 2016  06037980030                 0            0
# 2019  06037990100                 0            0
# 2020  06037990200                 0            0
#
#       Black or African American Alone  \
# ...

# %% [markdown]
# Imported the census data

# %%
tracts=gpd.read_file('Census_Tracts_2020.geojson')

# %%
tracts.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# Created a FIPS column to tracts data

# %%
tracts['FIPS'] ='06' + '037' + tracts['CT20']

# %%
tracts.head()
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0         1  101110  1011.10  1.229562e+07   15083.854287
# 1         2  101122  1011.22  2.845774e+07   31671.455844
# 2         3  101220  1012.20  7.522093e+06   12698.783810
# 3         4  101221  1012.21  3.812000e+06    9161.710543
# 4         5  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry         FIPS
# 0  POLYGON ((-118.28491 34.25948, -118.28492 34.2...  06037101110
# 1  POLYGON ((-118.29015 34.27417, -118.29015 34.2...  06037101122
# 2  POLYGON ((-118.28100 34.25592, -118.28198 34.2...  06037101220
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  POLYGON ((-118.28594 34.25405, -118.28594 34.2...  06037101222

# %% [markdown]
# Merged the data for both years

# %%
tracts_race_2010=tracts.merge(race_2010_2,on="FIPS")

# %%
tracts_race_2018=tracts.merge(race_2018_2,on="FIPS")

# %%
tracts_race_2010.plot(figsize=(12,10),
                 column='Black or African American Alone',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Mapped "Black or African American Alone" for both years

# %%
tracts_race_2018.plot(figsize=(12,10),
                 column='Black or African American Alone',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot: >

# %%
tracts_race_2010.plot(figsize=(12,10),
                 column='Black or African American Alone',
                 legend=True, 
                 scheme='quantiles')
# Out:
# <AxesSubplot: >

# %%
tracts_race_2018.plot(figsize=(12,10),
                 column='Black or African American Alone',
                 legend=True, 
                 scheme='quantiles')
# Out:
# <AxesSubplot: >
